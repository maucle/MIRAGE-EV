# %% [markdown]
# Visulizer:  Projects the corrected events on a larger canvas

# %%
import h5py
import numpy as np
import cv2

IN_H5   = "/home/maurice/Documents/Master_Data/RRS/Resolution/new/panorama_tilt_vectorized.h5"
OUT_MP4 = "/home/maurice/Documents/Master_Data/RRS/Resolution/new/sliding_window.mp4"

H, W = 1440, 1920
WINDOW = 30_000
FPS = 30

# Outside-window (persistent) mapping: usually needs a higher clip
CLIP_ACC = 50

# Current-window (live) mapping: usually smaller clip so it pops
CLIP_WIN = 5

# --- Rotation control for the sliding window overlay ---
MAX_ROT_DEG = 12.0         # clamp rotation magnitude
ROT_DEG_PER_PX = 0.03      # sensitivity: degrees per pixel of mean-y movement

def rotate_gray(img_u8, angle_deg):
    """Rotate a single-channel uint8 image around its center."""
    if angle_deg == 0:
        return img_u8
    center = (W / 2.0, H / 2.0)
    M = cv2.getRotationMatrix2D(center, angle_deg, 1.0)  # +angle = CCW
    return cv2.warpAffine(
        img_u8, M, (W, H),
        flags=cv2.INTER_NEAREST,
        borderMode=cv2.BORDER_CONSTANT,
        borderValue=0
    )

def counts_image_from_xy(xy, H, W):
    """Return (H,W) int32 count image from xy array (x,y)."""
    if xy.size == 0:
        return np.zeros((H, W), dtype=np.int32)

    x = xy[:, 0].astype(np.int64)
    y = xy[:, 1].astype(np.int64)

    # safety: ignore out-of-bounds events
    m = (x >= 0) & (x < W) & (y >= 0) & (y < H)
    x = x[m]; y = y[m]
    if x.size == 0:
        return np.zeros((H, W), dtype=np.int32)

    idx = y * W + x
    return np.bincount(idx, minlength=H * W).reshape(H, W).astype(np.int32)

with h5py.File(IN_H5, "r") as h5:
    dpos = h5["pos"]  # (N,3) x,y,t
    dneg = h5["neg"]  # (M,3) x,y,t

    tpos = dpos[:, 2] if dpos.shape[0] else np.array([], dtype=np.int64)
    tneg = dneg[:, 2] if dneg.shape[0] else np.array([], dtype=np.int64)

    t_min = min(tpos[0] if len(tpos) else 10**30,
                tneg[0] if len(tneg) else 10**30)
    t_max = max(tpos[-1] if len(tpos) else 0,
                tneg[-1] if len(tneg) else 0)

    times = np.arange(int(t_min), int(t_max), int(WINDOW))
    print("frames:", len(times), "WINDOW:", WINDOW, "duration:", int(t_max - t_min))

    pos_i0 = np.searchsorted(tpos, times, side="left") if len(tpos) else np.zeros(len(times), dtype=int)
    pos_i1 = np.searchsorted(tpos, times + WINDOW, side="left") if len(tpos) else np.zeros(len(times), dtype=int)
    neg_j0 = np.searchsorted(tneg, times, side="left") if len(tneg) else np.zeros(len(times), dtype=int)
    neg_j1 = np.searchsorted(tneg, times + WINDOW, side="left") if len(tneg) else np.zeros(len(times), dtype=int)

    # Persistent accumulation (includes everything up to current time)
    acc_pos = np.zeros((H, W), dtype=np.int32)
    acc_neg = np.zeros((H, W), dtype=np.int32)

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    vw = cv2.VideoWriter(OUT_MP4, fourcc, FPS, (W, H), isColor=True)

    # Track previous mean-y to determine motion direction
    prev_mean_y = None

    for k in range(len(times)):
        i0, i1 = int(pos_i0[k]), int(pos_i1[k])
        j0, j1 = int(neg_j0[k]), int(neg_j1[k])

        pos_xy = np.asarray(dpos[i0:i1, :2]) if i1 > i0 else np.zeros((0, 2), dtype=np.int64)
        neg_xy = np.asarray(dneg[j0:j1, :2]) if j1 > j0 else np.zeros((0, 2), dtype=np.int64)

        win_pos = counts_image_from_xy(pos_xy, H, W)
        win_neg = counts_image_from_xy(neg_xy, H, W)

        # Update accumulation
        acc_pos += win_pos
        acc_neg += win_neg

        # Outside-window layer (stable background)
        out_pos = np.maximum(acc_pos - win_pos, 0)
        out_neg = np.maximum(acc_neg - win_neg, 0)

        # Map to 8-bit (separately)
        out_pos8 = (np.clip(out_pos, 0, CLIP_ACC) * (255.0 / CLIP_ACC)).astype(np.uint8)
        out_neg8 = (np.clip(out_neg, 0, CLIP_ACC) * (255.0 / CLIP_ACC)).astype(np.uint8)

        win_pos8 = (np.clip(win_pos, 0, CLIP_WIN) * (255.0 / CLIP_WIN)).astype(np.uint8)
        win_neg8 = (np.clip(win_neg, 0, CLIP_WIN) * (255.0 / CLIP_WIN)).astype(np.uint8)

        # --- Compute overlay rotation based on y-direction ---
        # mean y of events in the current window (pos + neg)
        if pos_xy.size or neg_xy.size:
            ys = []
            if pos_xy.size:
                ys.append(pos_xy[:, 1].astype(np.float32))
            if neg_xy.size:
                ys.append(neg_xy[:, 1].astype(np.float32))
            all_y = np.concatenate(ys) if ys else None

            mean_y = float(np.mean(all_y)) if all_y is not None and all_y.size else prev_mean_y
        else:
            mean_y = prev_mean_y

        if prev_mean_y is None or mean_y is None:
            angle_deg = 0.0
        else:
            dy = mean_y - prev_mean_y

            # OpenCV image coords: y increases DOWN.
            # down (dy > 0)  -> clockwise      -> negative angle
            # up   (dy < 0)  -> counter-clock  -> positive angle
            angle_deg = float(np.clip(-dy * ROT_DEG_PER_PX, -MAX_ROT_DEG, MAX_ROT_DEG))

        prev_mean_y = mean_y

        # rotate ONLY the current-window overlay layers
        win_pos8r = rotate_gray(win_pos8, angle_deg)
        win_neg8r = rotate_gray(win_neg8, angle_deg)

        # Compose:
        # - background: pos=RED, neg=BLUE (like original)
        # - overlay current window: pos=GREEN, neg=CYAN (G+B) so it stands out
        bgr = np.zeros((H, W, 3), dtype=np.uint8)

        # background
        bgr[..., 2] = out_pos8  # R
        bgr[..., 0] = out_neg8  # B

        # overlay (use max so it doesn't darken anything)
        bgr[..., 1] = np.maximum(bgr[..., 1], win_pos8r)                  # G for current pos
        bgr[..., 0] = np.maximum(bgr[..., 0], win_neg8r)                  # B for current neg
        bgr[..., 1] = np.maximum(bgr[..., 1], win_neg8r // 2)             # add some G to make neg look cyan-ish

        vw.write(bgr)

    vw.release()

print("saved:", OUT_MP4)
# Out:
# frames: 682 WINDOW: 30000 duration: 20452983
# saved: /home/maurice/Documents/Master_Data/RRS/Resolution/new/sliding_window.mp4
